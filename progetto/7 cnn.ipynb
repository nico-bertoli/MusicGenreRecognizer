# %%
import matplotlib.pyplot as plt
import numpy as np

import tensorflow as tf
from tensorflow import keras

import librosa
import librosa.display
import IPython.display as ipd

import seaborn

from sklearn.metrics import confusion_matrix

# %%
    N_TRAIN_FILES = 60         #60
    N_TEST_FILES = 11          #11
    N_VALIDATION_FILES = 3     #3
    EPOCHS = 4                 #epochs interne    
    ACC_RICHIESTA = 0.74        # 0 -> ricerca accuratezza massima per questo modello
                               # n -> termina l' addestramento al raggiungimento di questa accuratezza, poi valuta il modello e stampa il log     

    DIM_IMMAGINI = '5x5'
    N_IMAGES_FOR_FILE = 100
    SPECTRS_FOLDER = '5spectrs'
    GENERI = ['blues','classical','dubstep','house','jazz','metal','pp','rap','reggae']

# %%
#METHODS
#-------------------------------------------------------------------------------------VISUALIZZAZIONE DELLO SPETTROGRAMMA
def plot_spectrogram(Y, sr, hop_length, y_axis="linear",title=""):
    # plt.figure(figsize=(25, 10))
    plt.figure(figsize=(12, 5))
    plt.title(title)
    librosa.display.specshow(Y, 
                             sr=sr, 
                             hop_length=hop_length, 
                             x_axis="time", 
                             y_axis=y_axis)
    plt.colorbar(format="%+2.f")
#------------------------------------------------------------------------------------
def contaPredCorrErr(valoriPredetti,valoriCorretti):
    valutazioniCorrette = 0
    valutazioniErrate = 0
    i=0
    for a in valoriCorretti:
        if a == valoriPredetti[i]:
            valutazioniCorrette+=1
        else:
            valutazioniErrate+=1
        i+=1
    
    return valutazioniCorrette,valutazioniErrate
#-------------------------------------------------------------------------------------
def shuffleTwo(a,b):
    s = np.arange(a.shape[0])
    np.random.shuffle(s)

    xris=a[s]
    yris=b[s]

    return xris,yris

#------------------------------------------------------------------------------------
def normalizza(val,min,max):
    norm = 2* (val-min)/(max-min) -1
    return norm
#------------------------------------------------------------------------------------
def normalizzaChunk(chunk,min,max):
    vT = np.vectorize(normalizza)
    i=0
    for immagine in chunk:
        chunk[i]=vT(immagine,min,max)
        i+=1
#------------------------------------------------------------------------------------
def normalizzaChunk(chunk,min,max):
    vT = np.vectorize(normalizza)
    i=0
    for immagine in chunk:
        chunk[i]=vT(immagine,min,max)
        i+=1
def plot_history(train_accuracy,test_accuracy,train_error,test_error):
    fig,axs = plt.subplots(2)
    #accuracy subplot
    axs[0].plot(train_accuracy,label='train')
    axs[0].plot(test_accuracy,label='validation')
    axs[0].set_ylabel('Accuracy')
    axs[0].legend(bbox_to_anchor=(1, 1), loc='lower right')
    # axs[0].legend(loc='lower right')
    # axs[0].set_title('Accuracy eval')

    #error subplot
    axs[1].plot(train_error,label='train error')
    axs[1].plot(test_error,label='test error')
    axs[1].set_ylabel('Error')
    axs[1].set_xlabel('Epoch')
    # axs[1].legend(bbox_to_anchor=(1.4, 1), loc='upper right')
    # axs[1].legend(loc='upper right')
    # axs[1].set_title('Error eval')

    plt.show()

# %%
#=========================================================
# ANALISI DEL DATASET
#=========================================================

# %%
analizza = np.load(f'{SPECTRS_FOLDER}/{GENERI[0]}/{GENERI[0]}0.npy')
img_height=analizza.shape[1]
img_width=analizza.shape[2]

print('larghezza immagini:'+str(img_width))
print('altezza immagini:'+str(img_height))

print(f'\nho {N_TRAIN_FILES} file  di training, {N_TEST_FILES} di test e ciascuno di queti contiene {N_IMAGES_FOR_FILE} immagini')
print(f'ogni singola immagine contiene valori di tipo: {analizza[0].dtype}')
print()
print('stampo un\' immagine di esempio:')
plt.matshow(analizza[0], fignum=None)

del(analizza)
# Out:
# larghezza immagini:279
# altezza immagini:271
#
# ho 60 file  di training, 11 di test e ciascuno di queti contiene 100 immagini
# ogni singola immagine contiene valori di tipo: float32
#
# stampo un' immagine di esempio:

# %%
#=========================================================
#PREPARAZIONE MODELLO
#=========================================================

# %%
#batch size -> numero di samples che vengono propagati nella rete prma che essa venga aggiornata.
#epochs -> indica il numero di volte in cui ciascun batch viene propagato nella rete

# build network topology
model = keras.Sequential()

# 1st conv layer
#numero di filtri,grid size,funzione di attivazine
model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(img_height,img_width,4)))
model.add(keras.layers.MaxPooling2D((6, 6), strides=(6, 6), padding='same'))
#normalizza l' attivazione dei layer, permette di velocizzare l' addestramento
model.add(keras.layers.BatchNormalization())

# # 2nd conv layer
model.add(keras.layers.Conv2D(32, (3, 3), activation='relu'))              
model.add(keras.layers.MaxPooling2D((3, 3), strides=(3, 3), padding='same'))
model.add(keras.layers.BatchNormalization())

# 3rd conv layer
model.add(keras.layers.Conv2D(32, (2, 2), activation='relu'))
model.add(keras.layers.MaxPooling2D((2, 2), strides=(2, 2), padding='same'))
model.add(keras.layers.BatchNormalization())

# flatten output and feed it into dense layer
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(64, activation='relu'))
#cerco di evitare l' overfitting
model.add(keras.layers.Dropout(0.5))

# output layer
model.add(keras.layers.Dense(len(GENERI), activation='softmax'))

# %%
# compile model
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
#=========================================================
#VALIDATION SET
#=========================================================

# %%
#VALIDATION DATA
#prelevo il validation set dagli ultimi file

if N_VALIDATION_FILES!=0:

        first_val_chunk = N_TEST_FILES+N_TRAIN_FILES
        last_val_chunk = N_TEST_FILES+N_TRAIN_FILES+N_VALIDATION_FILES-1

        #carico il primo chunk del primo genere
        print(f'carico il chunk: {first_val_chunk} del genere: {GENERI[0]}')
        X_validation_temp = np.load(f'{SPECTRS_FOLDER}/{GENERI[0]}/{GENERI[0]}'+str(first_val_chunk)+'.npy')

        #carico tutti gli altri chunk del primo genere
        for chunk in range (first_val_chunk+1,last_val_chunk+1):
            print(f'carico il chunk: {chunk} del genere: {GENERI[0]}')
            temp = np.load(f'{SPECTRS_FOLDER}/{GENERI[0]}/{GENERI[0]}'+str(chunk)+'.npy')
            X_validation_temp = np.concatenate((X_validation_temp,temp))

        #carico tutti i chunk di tutti gli altri generi
        for n_genere in range (1,len(GENERI)):
            for chunk in range(first_val_chunk,last_val_chunk+1):
                 print(f'carico il chunk: {chunk} del genere: {GENERI[n_genere]}')
                 genere = np.load(f'{SPECTRS_FOLDER}/{GENERI[n_genere]}/{GENERI[n_genere]}'+str(chunk)+'.npy')
                 X_validation_temp = np.concatenate((X_validation_temp,genere))

        y_validation_temp = np.zeros(N_IMAGES_FOR_FILE*N_VALIDATION_FILES,dtype=int)
        for n_genere in range(1,len(GENERI)):
                y_validation_temp = np.concatenate((y_validation_temp,np.ones(N_IMAGES_FOR_FILE*N_VALIDATION_FILES,dtype=int)*n_genere))

        X_validation_temp,y_validation_temp = shuffleTwo(X_validation_temp,y_validation_temp)

        # X_validation_temp = tf.expand_dims(X_validation_temp, axis=-1)

        X_validation = X_validation_temp
        y_validation = y_validation_temp

        print(f'dimensione X_validation per il plot:{X_validation.shape[0]}')
        print(f'dimensione y_validation per il plot:{y_validation.shape[0]}')
# Out:
# carico il chunk: 71 del genere: blues
# carico il chunk: 72 del genere: blues
# carico il chunk: 73 del genere: blues
# carico il chunk: 71 del genere: classical
# carico il chunk: 72 del genere: classical
# carico il chunk: 73 del genere: classical
# carico il chunk: 71 del genere: dubstep
# carico il chunk: 72 del genere: dubstep
# carico il chunk: 73 del genere: dubstep
# carico il chunk: 71 del genere: house
# carico il chunk: 72 del genere: house
# carico il chunk: 73 del genere: house
# carico il chunk: 71 del genere: jazz
# carico il chunk: 72 del genere: jazz
# carico il chunk: 73 del genere: jazz
# carico il chunk: 71 del genere: metal
# carico il chunk: 72 del genere: metal
# carico il chunk: 73 del genere: metal
# carico il chunk: 71 del genere: pp
# carico il chunk: 72 del genere: pp
# carico il chunk: 73 del genere: pp
# carico il chunk: 71 del genere: rap
# carico il chunk: 72 del genere: rap
# carico il chunk: 73 del genere: rap
# carico il chunk: 71 del genere: reggae
# carico il chunk: 72 del genere: reggae
# carico il chunk: 73 del genere: reggae
# dimensione X_validation per il plot:2700
# dimensione y_validation per il plot:2700

# %%
#=========================================================
#ADDESTRAMENTO
#=========================================================

# %%
#RICERCA MASSIMA ACCURATEZZA POSSIBILE

if ACC_RICHIESTA == 0:

    train_accuracy = []
    test_accuracy = []
    train_error = []
    test_error = []

    max_val_accuracy = 0.0

    for n_epoch in range(EPOCHS):
        for chunk_number in range(N_TRAIN_FILES):
            print(f'\nepoch:{n_epoch} chunk:{chunk_number}')
            #-----------------------------------------------------------------X_train_temp
            #inizialmente equivale al chunk del genere 0 (blues), poi gli concateno tutti gli altri generi con questo chunk_number
            X_train_temp = np.load(f'{SPECTRS_FOLDER}/{GENERI[0]}/{GENERI[0]}'+str(chunk_number)+'.npy')
            for n_genere in range (1,len(GENERI)):
                genere = np.load(f'{SPECTRS_FOLDER}/{GENERI[n_genere]}/{GENERI[n_genere]}'+str(chunk_number)+'.npy')
                X_train_temp = np.concatenate((X_train_temp,genere))

            #-----------------------------------------------------------------y_train_temp
            y_train_temp = np.zeros(N_IMAGES_FOR_FILE,dtype=int)
            for n_genere in range(1,len(GENERI)):
                y_train_temp = np.concatenate((y_train_temp,np.ones(N_IMAGES_FOR_FILE,dtype=int)*n_genere))

            #-----------------------------------------------------------------X_train, y_train
            X_train,y_train=shuffleTwo(X_train_temp,y_train_temp)
            #aggiungo una dimensione ad X_train, questo e' necessario per come funziona keras
            # X_train = tf.expand_dims(X_train, axis=-1)

            #---------------------------------------------------------------------------------------------------------------------------------------------salva nel grafico tutti i punti per ogni epoch
            history=model.fit(X_train, y_train, epochs=1,batch_size=32,validation_data=(X_validation,y_validation))

            #prendo i valori ottenuti dalle epoch 0 e da quella centrale
            train_accuracy.append(history.history['accuracy'])

            test_accuracy.append(history.history['val_accuracy'])
                
            train_error.append(history.history['loss'])

            test_error.append(history.history['val_loss'])

            if history.history['val_accuracy'][0] > max_val_accuracy: max_val_accuracy=history.history['val_accuracy'][0]
            print(f'massima accuratezza raggiunta:{max_val_accuracy}')

            del(history)

# %%
if ACC_RICHIESTA == 0: plot_history(train_accuracy,test_accuracy,train_error,test_error)

# %%
#se ho eseguito il blocco precedente utilizzo la massima accuratezza possibile individuata
if ACC_RICHIESTA == 0.0:
    ACC_RICHIESTA = max_val_accuracy

# %%
print('addestro la rete finche non ha accuratezza: '+str(ACC_RICHIESTA))
# Out:
# addestro la rete finche non ha accuratezza: 0.74

# %%
train_accuracy = []
test_accuracy = []
train_error = []
test_error = []

max_local_val_accuracy = 0.0
for n_epoch in range(100):
    if max_local_val_accuracy >= ACC_RICHIESTA: break
    for chunk_number in range(N_TRAIN_FILES):
        print(f'\nepoch:{n_epoch} chunk:{chunk_number}')
        #-----------------------------------------------------------------X_train_temp
        #inizialmente equivale al chunk del genere 0 (blues), poi gli concateno tutti gli altri generi con questo chunk_number
        X_train_temp = np.load(f'{SPECTRS_FOLDER}/{GENERI[0]}/{GENERI[0]}'+str(chunk_number)+'.npy')
        for n_genere in range (1,len(GENERI)):
            genere = np.load(f'{SPECTRS_FOLDER}/{GENERI[n_genere]}/{GENERI[n_genere]}'+str(chunk_number)+'.npy')
            X_train_temp = np.concatenate((X_train_temp,genere))

        #-----------------------------------------------------------------y_train_temp
        y_train_temp = np.zeros(N_IMAGES_FOR_FILE,dtype=int)
        for n_genere in range(1,len(GENERI)):
            y_train_temp = np.concatenate((y_train_temp,np.ones(N_IMAGES_FOR_FILE,dtype=int)*n_genere))

        #-----------------------------------------------------------------X_train, y_train
        X_train,y_train=shuffleTwo(X_train_temp,y_train_temp)
        #aggiungo una dimensione ad X_train, questo e' necessario per come funziona keras
        # X_train = tf.expand_dims(X_train, axis=-1)

        #---------------------------------------------------------------------------------------------------------------------------------------------salva nel grafico tutti i punti per ogni epoch
        history=model.fit(X_train, y_train, epochs=1,batch_size=32,validation_data=(X_validation,y_validation))

        #se voglio addestrare un modello guardo se ho raggiunto l' accuratezza richiesta

        if history.history['val_accuracy'][0] > max_local_val_accuracy: max_local_val_accuracy=history.history['val_accuracy'][0]
        print(f'massima accuratezza raggiunta localmente: {max_local_val_accuracy}')

        #prendo i valori ottenuti dalle epoch 0 e da quella centrale
        train_accuracy.append(history.history['accuracy'])
        test_accuracy.append(history.history['val_accuracy'])  
        train_error.append(history.history['loss'])
        test_error.append(history.history['val_loss'])

        if max_local_val_accuracy >= ACC_RICHIESTA: break

        del(history)
# Out:
# =============] - 19s 667ms/step - loss: 1.6618 - accuracy: 0.3856 - val_loss: 2.3620 - val_accuracy: 0.1589
# massima accuratezza raggiunta localmente: 0.15888889133930206
#
# epoch:0 chunk:5
# 29/29 [==============================] - 20s 703ms/step - loss: 1.5716 - accuracy: 0.4344 - val_loss: 2.4085 - val_accuracy: 0.1433
# massima accuratezza raggiunta localmente: 0.15888889133930206
#
# epoch:0 chunk:6
# 29/29 [==============================] - 20s 676ms/step - loss: 1.6126 - accuracy: 0.4167 - val_loss: 2.3964 - val_accuracy: 0.1537
# massima accuratezza raggiunta localmente: 0.15888889133930206
#
# epoch:0 chunk:7
# 29/29 [==============================] - 19s 670ms/step - loss: 1.5303 - accuracy: 0.4122 - val_loss: 2.4321 - val_accuracy: 0.1259
# massima accuratezza raggiunta localmente: 0.15888889133930206
#
# epoch:0 chunk:8
# 29/29 [==============================] - 21s 740ms/step - loss: 1.4714 - accuracy: 0.4656 - val_loss: 2.4321 - val_accuracy: 0.1211
# massima accuratezza raggiunta localmente: 0.15888889133930206
#
# epoch:0 chunk:9
# 29/29 [==============================] - 19s 671ms/step - loss: 1.4996 - accuracy: 0.4500 - val_loss: 2.3952 - val_accuracy: 0.1293
# massima accuratezza raggiunta localmente: 0.15888889133930206
#
# epoch:0 chunk:10
# 29/29 [==============================] - 20s 678ms/step - loss: 1.3788 - accuracy: 0.5122 - val_loss: 2.3882 - val_accuracy: 0.1307
# massima accuratezza raggiunta localmente: 0.15888889133930206
#
# epoch:0 chunk:11
# 29/29 [==============================] - 20s 677ms/step - loss: 1.4077 - accuracy: 0.4922 - val_loss: 2.3102 - val_accuracy: 0.1678
# massima accuratezza raggiunta localmente: 0.16777777671813965
#
# epoch:0 chunk:12
# 29/29 [==============================] - 20s 679ms/step - loss: 1.4332 - accuracy: 0.4956 - val_loss: 2.3006 - val_accuracy: 0.1800
# massima accuratezza raggiunta localmente: 0.18000000715255737
#
# epoch:0 chunk:13
# 29/29 [==============================] - 19s 671ms/step - loss: 1.3368 - accuracy: 0.5211 - val_loss: 2.2100 - val_accuracy: 0.1937
# massima accuratezza raggiunta localmente: 0.19370371103286743
#
# epoch:0 chunk:14
# 29/29 [==============================] - 20s 675ms/step - loss: 1.2992 - accuracy: 0.5278 - val_loss: 2.0284 - val_accuracy: 0.2307
# massima accuratezza raggiunta localmente: 0.2307407408952713
#
# epoch:0 chunk:15
# 29/29 [==============================] - 20s 675ms/step - loss: 1.3539 - accuracy: 0.5322 - val_loss: 1.8444 - val_accuracy: 0.2793
# massima accuratezza raggiunta localmente: 0.27925926446914673
#
# epoch:0 chunk:16
# 29/29 [==============================] - 20s 682ms/step - loss: 1.2768 - accuracy: 0.5611 - val_loss: 1.6033 - val_accuracy: 0.3819
# massima accuratezza raggiunta localmente: 0.38185185194015503
#
# epoch:0 chunk:17
# 29/29 [==============================] - 20s 676ms/step - loss: 1.2754 - accuracy: 0.5300 - val_loss: 1.5079 - val_accuracy: 0.4100
# massima accuratezza raggiunta localmente: 0.4099999964237213
#
# epoch:0 chunk:18
# 29/29 [==============================] - 20s 695ms/step - loss: 1.2351 - accuracy: 0.5622 - val_loss: 1.3078 - val_accuracy: 0.5122
# massima accuratezza raggiunta localmente: 0.5122222304344177
#
# epoch:0 chunk:19
# 29/29 [==============================] - 20s 674ms/step - loss: 1.2239 - accuracy: 0.5578 - val_loss: 1.2183 - val_accuracy: 0.5444
# massima accuratezza raggiunta localmente: 0.5444444417953491
#
# epoch:0 chunk:20
# 29/29 [==============================] - 20s 675ms/step - loss: 1.2373 - accuracy: 0.5733 - val_loss: 1.1194 - val_accuracy: 0.6067
# massima accuratezza raggiunta localmente: 0.6066666841506958
#
# epoch:0 chunk:21
# 29/29 [==============================] - 21s 722ms/step - loss: 1.1508 - accuracy: 0.5867 - val_loss: 1.0977 - val_accuracy: 0.6230
# massima accuratezza raggiunta localmente: 0.6229629516601562
#
# epoch:0 chunk:22
# 29/29 [==============================] - 20s 681ms/step - loss: 1.2448 - accuracy: 0.5756 - val_loss: 1.1163 - val_accuracy: 0.6263
# massima accuratezza raggiunta localmente: 0.6262962818145752
#
# epoch:0 chunk:23
# 29/29 [==============================] - 20s 677ms/step - loss: 1.1823 - accuracy: 0.5900 - val_loss: 1.1311 - val_accuracy: 0.6030
# massima accuratezza raggiunta localmente: 0.6262962818145752
#
# epoch:0 chunk:24
# 29/29 [==============================] - 20s 677ms/step - loss: 1.1876 - accuracy: 0.5867 - val_loss: 1.0549 - val_accuracy: 0.6241
# massima accuratezza raggiunta localmente: 0.6262962818145752
#
# epoch:0 chunk:25
# 29/29 [==============================] - 19s 670ms/step - loss: 1.1920 - accuracy: 0.5822 - val_loss: 1.0580 - val_accuracy: 0.6256
# massima accuratezza raggiunta localmente: 0.6262962818145752
#
# epoch:0 chunk:26
# 29/29 [==============================] - 19s 670ms/step - loss: 1.1136 - accuracy: 0.5989 - val_loss: 1.0653 - val_accuracy: 0.6048
# massima accuratezza raggiunta localmente: 0.6262962818145752
#
# epoch:0 chunk:27
# 29/29 [==============================] - 20s 674ms/step - loss: 1.1408 - accuracy: 0.6033 - val_loss: 1.1483 - val_accuracy: 0.6074
# massima accuratezza raggiunta localmente: 0.6262962818145752
#
# epoch:0 chunk:28
# 29/29 [==============================] - 20s 678ms/step - loss: 1.1442 - accuracy: 0.5989 - val_loss: 1.0625 - val_accuracy: 0.6393
# massima accuratezza raggiunta localmente: 0.6392592787742615
#
# epoch:0 chunk:29
# 29/29 [==============================] - 21s 711ms/step - loss: 1.1356 - accuracy: 0.6178 - val_loss: 1.0837 - val_accuracy: 0.6200
# massima accuratezza raggiunta localmente: 0.6392592787742615
#
# epoch:0 chunk:30
# 29/29 [==============================] - 20s 676ms/step - loss: 1.1021 - accuracy: 0.6133 - val_loss: 1.0146 - val_accuracy: 0.6363
# massima accuratezza raggiunta localmente: 0.6392592787742615
#
# epoch:0 chunk:31
# 29/29 [==============================] - 19s 668ms/step - loss: 1.0879 - accuracy: 0.6267 - val_loss: 1.0743 - val_accuracy: 0.6296
# massima accuratezza raggiunta localmente: 0.6392592787742615
#
# epoch:0 chunk:32
# 29/29 [==============================] - 19s 672ms/step - loss: 1.0812 - accuracy: 0.6200 - val_loss: 1.1402 - val_accuracy: 0.5896
# massima accuratezza raggiunta localmente: 0.6392592787742615
#
# epoch:0 chunk:33
# 29/29 [==============================] - 19s 669ms/step - loss: 1.0217 - accuracy: 0.6467 - val_loss: 1.0709 - val_accuracy: 0.6200
# massima accuratezza raggiunta localmente: 0.6392592787742615
#
# epoch:0 chunk:34
# 29/29 [==============================] - 20s 682ms/step - loss: 1.0580 - accuracy: 0.6478 - val_loss: 1.0339 - val_accuracy: 0.6348
# massima accuratezza raggiunta localmente: 0.6392592787742615
#
# epoch:0 chunk:35
# 29/29 [==============================] - 19s 670ms/step - loss: 1.1414 - accuracy: 0.6033 - val_loss: 1.0090 - val_accuracy: 0.6319
# massima accuratezza raggiunta localmente: 0.6392592787742615
#
# epoch:0 chunk:36
# 29/29 [==============================] - 19s 667ms/step - loss: 1.0118 - accuracy: 0.6511 - val_loss: 0.9787 - val_accuracy: 0.6426
# massima accuratezza raggiunta localmente: 0.6425926089286804
#
# epoch:0 chunk:37
# 29/29 [==============================] - 21s 736ms/step - loss: 1.0437 - accuracy: 0.6444 - val_loss: 0.9635 - val_accuracy: 0.6567
# massima accuratezza raggiunta localmente: 0.6566666960716248
#
# epoch:0 chunk:38
# 29/29 [==============================] - 21s 711ms/step - loss: 1.0184 - accuracy: 0.6289 - val_loss: 0.9614 - val_accuracy: 0.6604
# massima accuratezza raggiunta localmente: 0.6603703498840332
#
# epoch:0 chunk:39
# 29/29 [==============================] - 20s 679ms/step - loss: 1.0446 - accuracy: 0.6533 - val_loss: 0.9846 - val_accuracy: 0.6404
# massima accuratezza raggiunta localmente: 0.6603703498840332
#
# epoch:0 chunk:40
# 29/29 [==============================] - 20s 676ms/step - loss: 1.0583 - accuracy: 0.6489 - val_loss: 1.0977 - val_accuracy: 0.5607
# massima accuratezza raggiunta localmente: 0.6603703498840332
#
# epoch:0 chunk:41
# 29/29 [==============================] - 20s 694ms/step - loss: 1.0469 - accuracy: 0.6578 - val_loss: 0.9709 - val_accuracy: 0.6500
# massima accuratezza raggiunta localmente: 0.6603703498840332
#
# epoch:0 chunk:42
# 29/29 [==============================] - 20s 698ms/step - loss: 1.0018 - accuracy: 0.6622 - val_loss: 0.9403 - val_accuracy: 0.6667
# massima accuratezza raggiunta localmente: 0.6666666865348816
#
# epoch:0 chunk:43
# 29/29 [==============================] - 20s 688ms/step - loss: 1.0358 - accuracy: 0.6267 - val_loss: 0.9665 - val_accuracy: 0.6378
# massima accuratezza raggiunta localmente: 0.6666666865348816
#
# epoch:0 chunk:44
# 29/29 [==============================] - 19s 670ms/step - loss: 1.0147 - accuracy: 0.6511 - val_loss: 0.9152 - val_accuracy: 0.6756
# massima accuratezza raggiunta localmente: 0.6755555272102356
#
# epoch:0 chunk:45
# 29/29 [==============================] - 19s 658ms/step - loss: 0.9605 - accuracy: 0.6700 - val_loss: 0.9946 - val_accuracy: 0.6533
# massima accuratezza raggiunta localmente: 0.6755555272102356
#
# epoch:0 chunk:46
# 29/29 [==============================] - 19s 670ms/step - loss: 0.9943 - accuracy: 0.6533 - val_loss: 0.9472 - val_accuracy: 0.6567
# massima accuratezza raggiunta localmente: 0.6755555272102356
#
# epoch:0 chunk:47
# 29/29 [==============================] - 20s 675ms/step - loss: 0.9443 - accuracy: 0.6811 - val_loss: 0.9299 - val_accuracy: 0.6630
# massima accuratezza raggiunta localmente: 0.6755555272102356
#
# epoch:0 chunk:48
# 29/29 [==============================] - 19s 664ms/step - loss: 1.0218 - accuracy: 0.6456 - val_loss: 0.9481 - val_accuracy: 0.6570
# massima accuratezza raggiunta localmente: 0.6755555272102356
#
# epoch:0 chunk:49
# 29/29 [==============================] - 22s 750ms/step - loss: 0.9468 - accuracy: 0.6756 - val_loss: 0.9015 - val_accuracy: 0.6744
# massima accuratezza raggiunta localmente: 0.6755555272102356
#
# epoch:0 chunk:50
# 29/29 [==============================] - 19s 668ms/step - loss: 0.9224 - accuracy: 0.6767 - val_loss: 0.9238 - val_accuracy: 0.6652
# massima accuratezza raggiunta localmente: 0.6755555272102356
#
# epoch:0 chunk:51
# 29/29 [==============================] - 19s 661ms/step - loss: 0.9131 - accuracy: 0.6711 - val_loss: 0.9540 - val_accuracy: 0.6341
# massima accuratezza raggiunta localmente: 0.6755555272102356
#
# epoch:0 chunk:52
# 29/29 [==============================] - 20s 674ms/step - loss: 0.9633 - accuracy: 0.6856 - val_loss: 0.9181 - val_accuracy: 0.6852
# massima accuratezza raggiunta localmente: 0.6851851940155029
#
# epoch:0 chunk:53
# 29/29 [==============================] - 19s 672ms/step - loss: 0.9435 - accuracy: 0.6711 - val_loss: 0.8704 - val_accuracy: 0.6996
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:0 chunk:54
# 29/29 [==============================] - 19s 659ms/step - loss: 0.9402 - accuracy: 0.6644 - val_loss: 0.8719 - val_accuracy: 0.6807
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:0 chunk:55
# 29/29 [==============================] - 19s 662ms/step - loss: 0.8987 - accuracy: 0.6900 - val_loss: 0.8830 - val_accuracy: 0.6848
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:0 chunk:56
# 29/29 [==============================] - 19s 659ms/step - loss: 0.9119 - accuracy: 0.6989 - val_loss: 0.9035 - val_accuracy: 0.6830
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:0 chunk:57
# 29/29 [==============================] - 19s 664ms/step - loss: 0.9042 - accuracy: 0.6933 - val_loss: 1.0061 - val_accuracy: 0.6674
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:0 chunk:58
# 29/29 [==============================] - 21s 735ms/step - loss: 0.8849 - accuracy: 0.6922 - val_loss: 0.9455 - val_accuracy: 0.6756
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:0 chunk:59
# 29/29 [==============================] - 20s 691ms/step - loss: 0.8607 - accuracy: 0.7256 - val_loss: 0.9325 - val_accuracy: 0.6652
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:1 chunk:0
# 29/29 [==============================] - 20s 678ms/step - loss: 0.8938 - accuracy: 0.7067 - val_loss: 0.8811 - val_accuracy: 0.6822
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:1 chunk:1
# 29/29 [==============================] - 19s 668ms/step - loss: 0.9714 - accuracy: 0.6689 - val_loss: 0.9386 - val_accuracy: 0.6733
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:1 chunk:2
# 29/29 [==============================] - 19s 661ms/step - loss: 0.8386 - accuracy: 0.7100 - val_loss: 0.9659 - val_accuracy: 0.6733
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:1 chunk:3
# 29/29 [==============================] - 19s 662ms/step - loss: 0.8624 - accuracy: 0.7022 - val_loss: 0.8477 - val_accuracy: 0.6941
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:1 chunk:4
# 29/29 [==============================] - 19s 661ms/step - loss: 0.8408 - accuracy: 0.7178 - val_loss: 0.8507 - val_accuracy: 0.6948
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:1 chunk:5
# 29/29 [==============================] - 20s 675ms/step - loss: 0.8310 - accuracy: 0.7100 - val_loss: 0.8507 - val_accuracy: 0.6874
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:1 chunk:6
# 29/29 [==============================] - 19s 663ms/step - loss: 0.8393 - accuracy: 0.7056 - val_loss: 1.0150 - val_accuracy: 0.6174
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:1 chunk:7
# 29/29 [==============================] - 19s 668ms/step - loss: 0.8695 - accuracy: 0.7078 - val_loss: 0.9452 - val_accuracy: 0.6467
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:1 chunk:8
# 29/29 [==============================] - 20s 702ms/step - loss: 0.8051 - accuracy: 0.7167 - val_loss: 0.9194 - val_accuracy: 0.6641
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:1 chunk:9
# 29/29 [==============================] - 19s 664ms/step - loss: 0.8711 - accuracy: 0.7178 - val_loss: 1.0161 - val_accuracy: 0.6056
# massima accuratezza raggiunta localmente: 0.6996296048164368
#
# epoch:1 chunk:10
# 29/29 [==============================] - 19s 665ms/step - loss: 0.8576 - accuracy: 0.7122 - val_loss: 0.8363 - val_accuracy: 0.7044
# massima accuratezza raggiunta localmente: 0.7044444680213928
#
# epoch:1 chunk:11
# 29/29 [==============================] - 19s 671ms/step - loss: 0.8484 - accuracy: 0.7044 - val_loss: 0.8008 - val_accuracy: 0.7163
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:12
# 29/29 [==============================] - 20s 678ms/step - loss: 0.8311 - accuracy: 0.7144 - val_loss: 0.8158 - val_accuracy: 0.6985
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:13
# 29/29 [==============================] - 20s 680ms/step - loss: 0.8098 - accuracy: 0.7378 - val_loss: 0.8448 - val_accuracy: 0.6915
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:14
# 29/29 [==============================] - 21s 712ms/step - loss: 0.8404 - accuracy: 0.7133 - val_loss: 0.8532 - val_accuracy: 0.6900
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:15
# 29/29 [==============================] - 19s 670ms/step - loss: 0.8827 - accuracy: 0.6989 - val_loss: 0.9110 - val_accuracy: 0.6648
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:16
# 29/29 [==============================] - 19s 672ms/step - loss: 0.8382 - accuracy: 0.7044 - val_loss: 0.8811 - val_accuracy: 0.6656
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:17
# 29/29 [==============================] - 21s 711ms/step - loss: 0.8229 - accuracy: 0.7144 - val_loss: 0.8727 - val_accuracy: 0.6693
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:18
# 29/29 [==============================] - 20s 673ms/step - loss: 0.7720 - accuracy: 0.7344 - val_loss: 0.8536 - val_accuracy: 0.6652
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:19
# 29/29 [==============================] - 20s 689ms/step - loss: 0.7884 - accuracy: 0.7278 - val_loss: 0.8554 - val_accuracy: 0.6689
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:20
# 29/29 [==============================] - 20s 689ms/step - loss: 0.7930 - accuracy: 0.7222 - val_loss: 0.8943 - val_accuracy: 0.6778
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:21
# 29/29 [==============================] - 20s 684ms/step - loss: 0.7727 - accuracy: 0.7322 - val_loss: 0.9381 - val_accuracy: 0.6374
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:22
# 29/29 [==============================] - 20s 684ms/step - loss: 0.7824 - accuracy: 0.7389 - val_loss: 1.0839 - val_accuracy: 0.5481
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:23
# 29/29 [==============================] - 20s 673ms/step - loss: 0.8450 - accuracy: 0.7189 - val_loss: 0.9338 - val_accuracy: 0.6326
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:24
# 29/29 [==============================] - 20s 687ms/step - loss: 0.8099 - accuracy: 0.7311 - val_loss: 0.8904 - val_accuracy: 0.6674
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:25
# 29/29 [==============================] - 20s 682ms/step - loss: 0.7970 - accuracy: 0.7356 - val_loss: 0.8729 - val_accuracy: 0.6733
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:26
# 29/29 [==============================] - 20s 676ms/step - loss: 0.8347 - accuracy: 0.7200 - val_loss: 0.9503 - val_accuracy: 0.6670
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:27
# 29/29 [==============================] - 20s 693ms/step - loss: 0.7903 - accuracy: 0.7356 - val_loss: 0.8716 - val_accuracy: 0.6752
# massima accuratezza raggiunta localmente: 0.7162963151931763
#
# epoch:1 chunk:28
# 29/29 [==============================] - 19s 661ms/step - loss: 0.7765 - accuracy: 0.7356 - val_loss: 0.7739 - val_accuracy: 0.7200
# massima accuratezza raggiunta localmente: 0.7200000286102295
#
# epoch:1 chunk:29
# 29/29 [==============================] - 19s 660ms/step - loss: 0.8098 - accuracy: 0.7322 - val_loss: 0.7855 - val_accuracy: 0.7222
# massima accuratezza raggiunta localmente: 0.7222222089767456
#
# epoch:1 chunk:30
# 29/29 [==============================] - 20s 679ms/step - loss: 0.8155 - accuracy: 0.7378 - val_loss: 0.7776 - val_accuracy: 0.7226
# massima accuratezza raggiunta localmente: 0.7225925922393799
#
# epoch:1 chunk:31
# 29/29 [==============================] - 20s 682ms/step - loss: 0.8082 - accuracy: 0.7389 - val_loss: 0.7940 - val_accuracy: 0.7185
# massima accuratezza raggiunta localmente: 0.7225925922393799
#
# epoch:1 chunk:32
# 29/29 [==============================] - 19s 671ms/step - loss: 0.7872 - accuracy: 0.7289 - val_loss: 0.8091 - val_accuracy: 0.7048
# massima accuratezza raggiunta localmente: 0.7225925922393799
#
# epoch:1 chunk:33
# 29/29 [==============================] - 20s 693ms/step - loss: 0.7225 - accuracy: 0.7533 - val_loss: 0.8591 - val_accuracy: 0.7089
# massima accuratezza raggiunta localmente: 0.7225925922393799
#
# epoch:1 chunk:34
# 29/29 [==============================] - 20s 705ms/step - loss: 0.7822 - accuracy: 0.7322 - val_loss: 1.1652 - val_accuracy: 0.5974
# massima accuratezza raggiunta localmente: 0.7225925922393799
#
# epoch:1 chunk:35
# 29/29 [==============================] - 20s 677ms/step - loss: 0.8268 - accuracy: 0.7200 - val_loss: 0.8584 - val_accuracy: 0.7074
# massima accuratezza raggiunta localmente: 0.7225925922393799
#
# epoch:1 chunk:36
# 29/29 [==============================] - 20s 675ms/step - loss: 0.7134 - accuracy: 0.7556 - val_loss: 0.7934 - val_accuracy: 0.7259
# massima accuratezza raggiunta localmente: 0.7259259223937988
#
# epoch:1 chunk:37
# 29/29 [==============================] - 19s 672ms/step - loss: 0.7748 - accuracy: 0.7289 - val_loss: 0.9036 - val_accuracy: 0.6626
# massima accuratezza raggiunta localmente: 0.7259259223937988
#
# epoch:1 chunk:38
# 29/29 [==============================] - 19s 660ms/step - loss: 0.7529 - accuracy: 0.7456 - val_loss: 0.7645 - val_accuracy: 0.7407
# massima accuratezza raggiunta localmente: 0.7407407164573669

# %%
plot_history(train_accuracy,test_accuracy,train_error,test_error)

# %%
#=========================================================
#TEST SUL VALIDATION SET
#=========================================================

# %%
valutazioniCorrette = 0
valutazioniErrate = 0

for n in range (N_VALIDATION_FILES):

    nchunk = N_TEST_FILES+N_TRAIN_FILES+n

    print(f'analizzo il modello sul chunk:{nchunk}')

    #-----------------------------------------------------------------X_val_temp
    #carico il nuovo chunk del primo genere (blues)
    X_val_temp = np.load(f'{SPECTRS_FOLDER}/{GENERI[0]}/{GENERI[0]}'+str(nchunk)+'.npy')
    #poi carico il nuovo chunk di tutti gli altri generi
    for n_genere in range (1,len(GENERI)):
        genere = np.load(f'{SPECTRS_FOLDER}/{GENERI[n_genere]}/{GENERI[n_genere]}'+str(nchunk)+'.npy')
        X_val_temp = np.concatenate((X_val_temp,genere))

    #-----------------------------------------------------------------y_val_temp
    y_val_temp = np.zeros(N_IMAGES_FOR_FILE,dtype=int)
    for n_genere in range(1,len(GENERI)):
        y_val_temp = np.concatenate((y_val_temp,np.ones(N_IMAGES_FOR_FILE,dtype=int)*n_genere))

    #-----------------------------------------------------------------X_val, y_val
    X_val,y_val = shuffleTwo(X_val_temp,y_val_temp)
    # X_val = tf.expand_dims(X_val, axis=-1)
    #-----------------------------------------------------------------conteggi per valutazione modello
    #predizioni come probabilita' per ogni classe
    probPreds = model.predict(X_val)
    #predizione come classe con piu' altra probabilita' 
    testPreds = np.array([],dtype=int)
    for i in range(len(X_val)):
        testPreds=np.append(testPreds,np.argmax(probPreds[i]))

    #aggiorno il conteggio della valutazioni corrette e di quelle errate
    valut_corr,valut_err = contaPredCorrErr(testPreds,y_val)
    valutazioniCorrette+=valut_corr
    valutazioniErrate+=valut_err

#man mano calcolo le matrici di confusione e le somme nella totale
    if n==0:
        cm = confusion_matrix(y_val,testPreds)
    else:
        cm_temp = confusion_matrix(y_val,testPreds)
        cm+=cm_temp

    #gray scale
    cmap = seaborn.cubehelix_palette(50, hue=0.05, rot=0, light=0.9, dark=0, as_cmap=True)
    #nomi dei generi
    seaborn.heatmap(cm,annot=True,fmt="d",cmap=cmap,xticklabels=GENERI,yticklabels=GENERI)

    #volendo potrei utilizzare questa funzione per valutare la precisione del modello, il problema e' che ho tanti dati e quindi lo posso usare solamente sui chunk, non sul totale delle
    #previsioni,quindi ho deciso di usare il sistema dei conteggi per poi calcolare la precisione in modo manuale
    # test_loss, test_acc = model.evaluate(X_val, y_val)
    # print(f"Test Accuracy: {test_acc}")

#-----------------------------------------------------------------valutazione modello
precisioneValidationSet = valutazioniCorrette/(valutazioniCorrette+valutazioniErrate)
print(f'\n\nvalutazioni corrette: {valutazioniCorrette}')
print(f'valutazioni errate: {valutazioniErrate}')
print(f'precisione:{precisioneValidationSet}')
# Out:
# analizzo il modello sul chunk:71
# analizzo il modello sul chunk:72
# analizzo il modello sul chunk:73
#
#
# valutazioni corrette: 2000
# valutazioni errate: 700
# precisione:0.7407407407407407

# %%
#=========================================================
#TEST SUL TEST SET
#=========================================================

# %%
if ACC_RICHIESTA!=0:
    valutazioniCorrette = 0
    valutazioniErrate = 0


    for nchunk in range (N_TEST_FILES):
        #-----------------------------------------------------------------X_test_temp
        #carico il nuovo chunk del primo genere (blues)
        X_test_temp = np.load(f'{SPECTRS_FOLDER}/{GENERI[0]}/{GENERI[0]}'+str(nchunk+N_TRAIN_FILES)+'.npy')
        print(f'analizzo il modello sul chunk:{nchunk+N_TRAIN_FILES}')
        #poi carico i chunk di tutti gli altri generi
        for n_genere in range (1,len(GENERI)):
            genere = np.load(f'{SPECTRS_FOLDER}/{GENERI[n_genere]}/{GENERI[n_genere]}'+str(nchunk+N_TRAIN_FILES)+'.npy')
            X_test_temp = np.concatenate((X_test_temp,genere))
    
        #-----------------------------------------------------------------y_test_temp
        y_test_temp = np.zeros(N_IMAGES_FOR_FILE,dtype=int)
        for n_genere in range(1,len(GENERI)):
            y_test_temp = np.concatenate((y_test_temp,np.ones(N_IMAGES_FOR_FILE,dtype=int)*n_genere))

        #-----------------------------------------------------------------xtest, y_test
        X_test,y_test = shuffleTwo(X_test_temp,y_test_temp)
        # X_test = tf.expand_dims(X_test, axis=-1)
        #-----------------------------------------------------------------conteggi per valutazione modello
        #predizioni come probabilita' per ogni classe
        probPreds = model.predict(X_test)

        #predizione come classe con piu' altra probabilita' 
        testPreds = np.array([],dtype=int)
        for i in range(len(X_test)):
            testPreds=np.append(testPreds,np.argmax(probPreds[i]))

        #aggiorno il conteggio della valutazioni corrette e di quelle errate
        valut_corr,valut_err = contaPredCorrErr(testPreds,y_test)
        valutazioniCorrette+=valut_corr
        valutazioniErrate+=valut_err

    #man mano calcolo le matrici di confusione e le somme nella totale
        if nchunk==0:
            cm = confusion_matrix(y_test,testPreds)
        else:
            cm_temp = confusion_matrix(y_test,testPreds)
            cm+=cm_temp

    #grayscale
    cmap = seaborn.cubehelix_palette(50, hue=0.05, rot=0, light=0.9, dark=0, as_cmap=True)
    #nomi dei generi
    seaborn.heatmap(cm,annot=True,fmt="d",cmap=cmap,xticklabels=GENERI,yticklabels=GENERI)

        #volendo potrei utilizzare questa funzione per valutare la precisione del modello, il problema e' che ho tanti dati e quindi lo posso usare solamente sui chunk, non sul totale delle
        #previsioni,quindi ho deciso di usare il sistema dei conteggi per poi calcolare la precisione in modo manuale
        # test_loss, test_acc = model.evaluate(X_test, y_test)
        # print(f"Test Accuracy: {test_acc}")

    #-----------------------------------------------------------------valutazione modello
    precisioneTestSet = valutazioniCorrette/(valutazioniCorrette+valutazioniErrate)
    print(f'\n\nvalutazioni corrette: {valutazioniCorrette}')
    print(f'valutazioni errate: {valutazioniErrate}')
    print(f'precisione:{precisioneTestSet}')
# Out:
# analizzo il modello sul chunk:60
# analizzo il modello sul chunk:61
# analizzo il modello sul chunk:62
# analizzo il modello sul chunk:63
# analizzo il modello sul chunk:64
# analizzo il modello sul chunk:65
# analizzo il modello sul chunk:66
# analizzo il modello sul chunk:67
# analizzo il modello sul chunk:68
# analizzo il modello sul chunk:69
# analizzo il modello sul chunk:70
#
#
# valutazioni corrette: 7574
# valutazioni errate: 2326
# precisione:0.7650505050505051

# %%
#=========================================================
#TEST SUL TRAININIG SET
#=========================================================

# %%
if ACC_RICHIESTA!=0:

    valutazioniCorrette = 0
    valutazioniErrate = 0

    for nchunk in range (N_TRAIN_FILES):

        print(f'analizzo il modello sul chunk:{nchunk}')

        #-----------------------------------------------------------------X_train_temp
        #carico il nuovo chunk del primo genere (blues)
        X_train_temp = np.load(f'{SPECTRS_FOLDER}/{GENERI[0]}/{GENERI[0]}'+str(nchunk)+'.npy')
        #poi carico il nuovo chunk di tutti gli altri generi
        for n_genere in range (1,len(GENERI)):
            genere = np.load(f'{SPECTRS_FOLDER}/{GENERI[n_genere]}/{GENERI[n_genere]}'+str(nchunk)+'.npy')
            X_train_temp = np.concatenate((X_train_temp,genere))

        #-----------------------------------------------------------------y_train_temp
        y_train_temp = np.zeros(N_IMAGES_FOR_FILE,dtype=int)
        for n_genere in range(1,len(GENERI)):
            y_train_temp = np.concatenate((y_train_temp,np.ones(N_IMAGES_FOR_FILE,dtype=int)*n_genere))

        #-----------------------------------------------------------------X_train, y_train
        X_train,y_train = shuffleTwo(X_train_temp,y_train_temp)
        # X_train = tf.expand_dims(X_train, axis=-1)
        #-----------------------------------------------------------------conteggi per valutazione modello
        #predizioni come probabilita' per ogni classe
        probPreds = model.predict(X_train)
        #predizione come classe con piu' altra probabilita' 
        testPreds = np.array([],dtype=int)
        for i in range(len(X_train)):
            testPreds=np.append(testPreds,np.argmax(probPreds[i]))

        #aggiorno il conteggio della valutazioni corrette e di quelle errate
        valut_corr,valut_err = contaPredCorrErr(testPreds,y_train)
        valutazioniCorrette+=valut_corr
        valutazioniErrate+=valut_err

    #man mano calcolo le matrici di confusione e le somme nella totale
        if nchunk==0:
            cm = confusion_matrix(y_train,testPreds)
        else:
            cm_temp = confusion_matrix(y_train,testPreds)
            cm+=cm_temp

    #grayscale
    cmap = seaborn.cubehelix_palette(50, hue=0.05, rot=0, light=0.9, dark=0, as_cmap=True)
    #nomi dei generi
    seaborn.heatmap(cm,annot=True,fmt="d",cmap=cmap,xticklabels=GENERI,yticklabels=GENERI)

        #volendo potrei utilizzare questa funzione per valutare la precisione del modello, il problema e' che ho tanti dati e quindi lo posso usare solamente sui chunk, non sul totale delle
        #previsioni,quindi ho deciso di usare il sistema dei conteggi per poi calcolare la precisione in modo manuale
        # test_loss, test_acc = model.evaluate(X_train, y_train)
        # print(f"Test Accuracy: {test_acc}")

    #-----------------------------------------------------------------valutazione modello
    precisioneTrainSet = valutazioniCorrette/(valutazioniCorrette+valutazioniErrate)
    print(f'\n\nvalutazioni corrette: {valutazioniCorrette}')
    print(f'valutazioni errate: {valutazioniErrate}')
    print(f'precisione:{precisioneTrainSet}')
# Out:
# analizzo il modello sul chunk:0
# analizzo il modello sul chunk:1
# analizzo il modello sul chunk:2
# analizzo il modello sul chunk:3
# analizzo il modello sul chunk:4
# analizzo il modello sul chunk:5
# analizzo il modello sul chunk:6
# analizzo il modello sul chunk:7
# analizzo il modello sul chunk:8
# analizzo il modello sul chunk:9
# analizzo il modello sul chunk:10
# analizzo il modello sul chunk:11
# analizzo il modello sul chunk:12
# analizzo il modello sul chunk:13
# analizzo il modello sul chunk:14
# analizzo il modello sul chunk:15
# analizzo il modello sul chunk:16
# analizzo il modello sul chunk:17
# analizzo il modello sul chunk:18
# analizzo il modello sul chunk:19
# analizzo il modello sul chunk:20
# analizzo il modello sul chunk:21
# analizzo il modello sul chunk:22
# analizzo il modello sul chunk:23
# analizzo il modello sul chunk:24
# analizzo il modello sul chunk:25
# analizzo il modello sul chunk:26
# analizzo il modello sul chunk:27
# analizzo il modello sul chunk:28
# analizzo il modello sul chunk:29
# analizzo il modello sul chunk:30
# analizzo il modello sul chunk:31
# analizzo il modello sul chunk:32
# analizzo il modello sul chunk:33
# analizzo il modello sul chunk:34
# analizzo il modello sul chunk:35
# analizzo il modello sul chunk:36
# analizzo il modello sul chunk:37
# analizzo il modello sul chunk:38
# analizzo il modello sul chunk:39
# analizzo il modello sul chunk:40
# analizzo il modello sul chunk:41
# analizzo il modello sul chunk:42
# analizzo il modello sul chunk:43
# analizzo il modello sul chunk:44
# analizzo il modello sul chunk:45
# analizzo il modello sul chunk:46
# analizzo il modello sul chunk:47
# analizzo il modello sul chunk:48
# analizzo il modello sul chunk:49
# analizzo il modello sul chunk:50
# analizzo il modello sul chunk:51
# analizzo il modello sul chunk:52
# analizzo il modello sul chunk:53
# analizzo il modello sul chunk:54
# analizzo il modello sul chunk:55
# analizzo il modello sul chunk:56
# analizzo il modello sul chunk:57
# analizzo il modello sul chunk:58
# analizzo il modello sul chunk:59
#
#
# valutazioni corrette: 43832
# valutazioni errate: 10168
# precisione:0.8117037037037037

# %%
with open('log.txt','a')as log:
    log.write(f'dimensione immagini: {DIM_IMMAGINI}\n')
    log.write(f'TOT FILES: {N_TRAIN_FILES+N_TEST_FILES+N_VALIDATION_FILES}\n')
    log.write(f'TRAIN FILES: {N_TRAIN_FILES}\n')
    log.write(f'VALIDATION FILES: {N_TEST_FILES}\n')
    log.write(f'TEST FILES: {  N_TEST_FILES}\n')
    log.write(f'EPOCHS: {EPOCHS}\n\n')

    log.write(f'PRECISIONE VALIDATION SET: {precisioneValidationSet}\n')
    log.write(f'PRECISIONE TEST SET: {precisioneTestSet}\n')
    log.write(f'PRECISIONE TRAIN SET: {precisioneTrainSet}\n\n')

    model.summary(print_fn=lambda x: log.write(x + '\n'))

    log.write('\n\n\n')
    log.write(f'//////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////////')
    log.write('\n\n\n\n')

# %%
print('END')
# Out:
# END

# %%
# model.save('./model')

# %%
# model = keras.model.load_model('percorso')
