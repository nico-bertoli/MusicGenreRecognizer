# %%
import os
import numpy
import librosa
import librosa.display
import IPython.display as ipd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow import keras

# %%
    NDIGITS = 4               #digits of the number of files (if I have 2000 files it's 4)
    N_INPUT_FILES = 1400     #1400    (numero file del test set) 
    START = 6001           #6001
    GENERE='pp'

    INPUT_FOLDER = '1wav15/'+GENERE          #name of the folder that contains wav files
    FILEBEGINNING = GENERE+'_'                #beginnig of the name of each file
    OUTPUT_FOLDER = '2timestamps/'+GENERE+'/'

# %%
#TODO tradurre in inglese da qui in poi
#FUNCTIONS
#---------------------------------------------------------------------------------------GET ADDRESSES
# returns a lit with the names of wav files
def getAddresses (folderName,fileName,nFile = N_INPUT_FILES,nDigits = NDIGITS):
    #str(x).zfill adds zeros at the beginning of the number (es 4 -> 0004)
    n = [str(x).zfill(nDigits) for x in range(START,nFile+START)]
    #list with name of files
    ris = []
    for i in n:
       ris.append(f'{folderName}/{fileName}{i}.wav')
    return ris

#---------------------------------------------------------------------------------------GET AUDIOS
# input:
# adresses -> list with the names of wav files
#
# output:
# - wav files timestamps
# - theyr sample rate (I assume they have all the same sr)
def getAudios(addresses,nfiles = N_INPUT_FILES):
    ris = []
    #returns the timestamp and sample rate of the file
    inutile,sr = librosa.load(addresses[0]) 

    #TODO: PROVA A RIMUOVORE inutile
    for x in addresses:
        audio,inutile = librosa.load(x)
        ris.append(audio)
        print('carico il file '+x+f', {nfiles} files remaining')
        nfiles-=1

    return ris,sr

# %%
#GET THE ADRESSES OF ALL FILES (A LIST FOR EACH GENRE)
addresses = getAddresses(INPUT_FOLDER,FILEBEGINNING)

#formato ottenuto:
print(f'tipo del formato ottenuto: {addresses[0]}')
# Out:
# tipo del formato ottenuto: 1wav15/pp/pp_6001.wav

# %%
if len(addresses)==N_INPUT_FILES : print('addresses calculated with success')
# Out:
# addresses calculated with success

# %%
#GET THE AUDIOS
audios,sr = getAudios(addresses)

#ottengo un array di audio time series
#un audio time serie e' un array di valori che corrispondono ai sample del file nel tempo
# Out:
# v15/pp/pp_7054.wav, 347 files remaining
# carico il file 1wav15/pp/pp_7055.wav, 346 files remaining
# carico il file 1wav15/pp/pp_7056.wav, 345 files remaining
# carico il file 1wav15/pp/pp_7057.wav, 344 files remaining
# carico il file 1wav15/pp/pp_7058.wav, 343 files remaining
# carico il file 1wav15/pp/pp_7059.wav, 342 files remaining
# carico il file 1wav15/pp/pp_7060.wav, 341 files remaining
# carico il file 1wav15/pp/pp_7061.wav, 340 files remaining
# carico il file 1wav15/pp/pp_7062.wav, 339 files remaining
# carico il file 1wav15/pp/pp_7063.wav, 338 files remaining
# carico il file 1wav15/pp/pp_7064.wav, 337 files remaining
# carico il file 1wav15/pp/pp_7065.wav, 336 files remaining
# carico il file 1wav15/pp/pp_7066.wav, 335 files remaining
# carico il file 1wav15/pp/pp_7067.wav, 334 files remaining
# carico il file 1wav15/pp/pp_7068.wav, 333 files remaining
# carico il file 1wav15/pp/pp_7069.wav, 332 files remaining
# carico il file 1wav15/pp/pp_7070.wav, 331 files remaining
# carico il file 1wav15/pp/pp_7071.wav, 330 files remaining
# carico il file 1wav15/pp/pp_7072.wav, 329 files remaining
# carico il file 1wav15/pp/pp_7073.wav, 328 files remaining
# carico il file 1wav15/pp/pp_7074.wav, 327 files remaining
# carico il file 1wav15/pp/pp_7075.wav, 326 files remaining
# carico il file 1wav15/pp/pp_7076.wav, 325 files remaining
# carico il file 1wav15/pp/pp_7077.wav, 324 files remaining
# carico il file 1wav15/pp/pp_7078.wav, 323 files remaining
# carico il file 1wav15/pp/pp_7079.wav, 322 files remaining
# carico il file 1wav15/pp/pp_7080.wav, 321 files remaining
# carico il file 1wav15/pp/pp_7081.wav, 320 files remaining
# carico il file 1wav15/pp/pp_7082.wav, 319 files remaining
# carico il file 1wav15/pp/pp_7083.wav, 318 files remaining
# carico il file 1wav15/pp/pp_7084.wav, 317 files remaining
# carico il file 1wav15/pp/pp_7085.wav, 316 files remaining
# carico il file 1wav15/pp/pp_7086.wav, 315 files remaining
# carico il file 1wav15/pp/pp_7087.wav, 314 files remaining
# carico il file 1wav15/pp/pp_7088.wav, 313 files remaining
# carico il file 1wav15/pp/pp_7089.wav, 312 files remaining
# carico il file 1wav15/pp/pp_7090.wav, 311 files remaining
# carico il file 1wav15/pp/pp_7091.wav, 310 files remaining
# carico il file 1wav15/pp/pp_7092.wav, 309 files remaining
# carico il file 1wav15/pp/pp_7093.wav, 308 files remaining
# carico il file 1wav15/pp/pp_7094.wav, 307 files remaining
# carico il file 1wav15/pp/pp_7095.wav, 306 files remaining
# carico il file 1wav15/pp/pp_7096.wav, 305 files remaining
# carico il file 1wav15/pp/pp_7097.wav, 304 files remaining
# carico il file 1wav15/pp/pp_7098.wav, 303 files remaining
# carico il file 1wav15/pp/pp_7099.wav, 302 files remaining
# carico il file 1wav15/pp/pp_7100.wav, 301 files remaining
# carico il file 1wav15/pp/pp_7101.wav, 300 files remaining
# carico il file 1wav15/pp/pp_7102.wav, 299 files remaining
# carico il file 1wav15/pp/pp_7103.wav, 298 files remaining
# carico il file 1wav15/pp/pp_7104.wav, 297 files remaining
# carico il file 1wav15/pp/pp_7105.wav, 296 files remaining
# carico il file 1wav15/pp/pp_7106.wav, 295 files remaining
# carico il file 1wav15/pp/pp_7107.wav, 294 files remaining
# carico il file 1wav15/pp/pp_7108.wav, 293 files remaining
# carico il file 1wav15/pp/pp_7109.wav, 292 files remaining
# carico il file 1wav15/pp/pp_7110.wav, 291 files remaining
# carico il file 1wav15/pp/pp_7111.wav, 290 files remaining
# carico il file 1wav15/pp/pp_7112.wav, 289 files remaining
# carico il file 1wav15/pp/pp_7113.wav, 288 files remaining
# carico il file 1wav15/pp/pp_7114.wav, 287 files remaining
# carico il file 1wav15/pp/pp_7115.wav, 286 files remaining
# carico il file 1wav15/pp/pp_7116.wav, 285 files remaining
# carico il file 1wav15/pp/pp_7117.wav, 284 files remaining
# carico il file 1wav15/pp/pp_7118.wav, 283 files remaining
# carico il file 1wav15/pp/pp_7119.wav, 282 files remaining
# carico il file 1wav15/pp/pp_7120.wav, 281 files remaining
# carico il file 1wav15/pp/pp_7121.wav, 280 files remaining
# carico il file 1wav15/pp/pp_7122.wav, 279 files remaining
# carico il file 1wav15/pp/pp_7123.wav, 278 files remaining
# carico il file 1wav15/pp/pp_7124.wav, 277 files remaining
# carico il file 1wav15/pp/pp_7125.wav, 276 files remaining
# carico il file 1wav15/pp/pp_7126.wav, 275 files remaining
# carico il file 1wav15/pp/pp_7127.wav, 274 files remaining
# carico il file 1wav15/pp/pp_7128.wav, 273 files remaining
# carico il file 1wav15/pp/pp_7129.wav, 272 files remaining
# carico il file 1wav15/pp/pp_7130.wav, 271 files remaining
# carico il file 1wav15/pp/pp_7131.wav, 270 files remaining
# carico il file 1wav15/pp/pp_7132.wav, 269 files remaining
# carico il file 1wav15/pp/pp_7133.wav, 268 files remaining
# carico il file 1wav15/pp/pp_7134.wav, 267 files remaining
# carico il file 1wav15/pp/pp_7135.wav, 266 files remaining
# carico il file 1wav15/pp/pp_7136.wav, 265 files remaining
# carico il file 1wav15/pp/pp_7137.wav, 264 files remaining
# carico il file 1wav15/pp/pp_7138.wav, 263 files remaining
# carico il file 1wav15/pp/pp_7139.wav, 262 files remaining
# carico il file 1wav15/pp/pp_7140.wav, 261 files remaining
# carico il file 1wav15/pp/pp_7141.wav, 260 files remaining
# carico il file 1wav15/pp/pp_7142.wav, 259 files remaining
# carico il file 1wav15/pp/pp_7143.wav, 258 files remaining
# carico il file 1wav15/pp/pp_7144.wav, 257 files remaining
# carico il file 1wav15/pp/pp_7145.wav, 256 files remaining
# carico il file 1wav15/pp/pp_7146.wav, 255 files remaining
# carico il file 1wav15/pp/pp_7147.wav, 254 files remaining
# carico il file 1wav15/pp/pp_7148.wav, 253 files remaining
# carico il file 1wav15/pp/pp_7149.wav, 252 files remaining
# carico il file 1wav15/pp/pp_7150.wav, 251 files remaining
# carico il file 1wav15/pp/pp_7151.wav, 250 files remaining
# carico il file 1wav15/pp/pp_7152.wav, 249 files remaining
# carico il file 1wav15/pp/pp_7153.wav, 248 files remaining
# carico il file 1wav15/pp/pp_7154.wav, 247 files remaining
# carico il file 1wav15/pp/pp_7155.wav, 246 files remaining
# carico il file 1wav15/pp/pp_7156.wav, 245 files remaining
# carico il file 1wav15/pp/pp_7157.wav, 244 files remaining
# carico il file 1wav15/pp/pp_7158.wav, 243 files remaining
# carico il file 1wav15/pp/pp_7159.wav, 242 files remaining
# carico il file 1wav15/pp/pp_7160.wav, 241 files remaining
# carico il file 1wav15/pp/pp_7161.wav, 240 files remaining
# carico il file 1wav15/pp/pp_7162.wav, 239 files remaining
# carico il file 1wav15/pp/pp_7163.wav, 238 files remaining
# carico il file 1wav15/pp/pp_7164.wav, 237 files remaining
# carico il file 1wav15/pp/pp_7165.wav, 236 files remaining
# carico il file 1wav15/pp/pp_7166.wav, 235 files remaining
# carico il file 1wav15/pp/pp_7167.wav, 234 files remaining
# carico il file 1wav15/pp/pp_7168.wav, 233 files remaining
# carico il file 1wav15/pp/pp_7169.wav, 232 files remaining
# carico il file 1wav15/pp/pp_7170.wav, 231 files remaining
# carico il file 1wav15/pp/pp_7171.wav, 230 files remaining
# carico il file 1wav15/pp/pp_7172.wav, 229 files remaining
# carico il file 1wav15/pp/pp_7173.wav, 228 files remaining
# carico il file 1wav15/pp/pp_7174.wav, 227 files remaining
# carico il file 1wav15/pp/pp_7175.wav, 226 files remaining
# carico il file 1wav15/pp/pp_7176.wav, 225 files remaining
# carico il file 1wav15/pp/pp_7177.wav, 224 files remaining
# carico il file 1wav15/pp/pp_7178.wav, 223 files remaining
# carico il file 1wav15/pp/pp_7179.wav, 222 files remaining
# carico il file 1wav15/pp/pp_7180.wav, 221 files remaining
# carico il file 1wav15/pp/pp_7181.wav, 220 files remaining
# carico il file 1wav15/pp/pp_7182.wav, 219 files remaining
# carico il file 1wav15/pp/pp_7183.wav, 218 files remaining
# carico il file 1wav15/pp/pp_7184.wav, 217 files remaining
# carico il file 1wav15/pp/pp_7185.wav, 216 files remaining
# carico il file 1wav15/pp/pp_7186.wav, 215 files remaining
# carico il file 1wav15/pp/pp_7187.wav, 214 files remaining
# carico il file 1wav15/pp/pp_7188.wav, 213 files remaining
# carico il file 1wav15/pp/pp_7189.wav, 212 files remaining
# carico il file 1wav15/pp/pp_7190.wav, 211 files remaining
# carico il file 1wav15/pp/pp_7191.wav, 210 files remaining
# carico il file 1wav15/pp/pp_7192.wav, 209 files remaining
# carico il file 1wav15/pp/pp_7193.wav, 208 files remaining
# carico il file 1wav15/pp/pp_7194.wav, 207 files remaining
# carico il file 1wav15/pp/pp_7195.wav, 206 files remaining
# carico il file 1wav15/pp/pp_7196.wav, 205 files remaining
# carico il file 1wav15/pp/pp_7197.wav, 204 files remaining
# carico il file 1wav15/pp/pp_7198.wav, 203 files remaining
# carico il file 1wav15/pp/pp_7199.wav, 202 files remaining
# carico il file 1wav15/pp/pp_7200.wav, 201 files remaining
# carico il file 1wav15/pp/pp_7201.wav, 200 files remaining
# carico il file 1wav15/pp/pp_7202.wav, 199 files remaining
# carico il file 1wav15/pp/pp_7203.wav, 198 files remaining
# carico il file 1wav15/pp/pp_7204.wav, 197 files remaining
# carico il file 1wav15/pp/pp_7205.wav, 196 files remaining
# carico il file 1wav15/pp/pp_7206.wav, 195 files remaining
# carico il file 1wav15/pp/pp_7207.wav, 194 files remaining
# carico il file 1wav15/pp/pp_7208.wav, 193 files remaining
# carico il file 1wav15/pp/pp_7209.wav, 192 files remaining
# carico il file 1wav15/pp/pp_7210.wav, 191 files remaining
# carico il file 1wav15/pp/pp_7211.wav, 190 files remaining
# carico il file 1wav15/pp/pp_7212.wav, 189 files remaining
# carico il file 1wav15/pp/pp_7213.wav, 188 files remaining
# carico il file 1wav15/pp/pp_7214.wav, 187 files remaining
# carico il file 1wav15/pp/pp_7215.wav, 186 files remaining
# carico il file 1wav15/pp/pp_7216.wav, 185 files remaining
# carico il file 1wav15/pp/pp_7217.wav, 184 files remaining
# carico il file 1wav15/pp/pp_7218.wav, 183 files remaining
# carico il file 1wav15/pp/pp_7219.wav, 182 files remaining
# carico il file 1wav15/pp/pp_7220.wav, 181 files remaining
# carico il file 1wav15/pp/pp_7221.wav, 180 files remaining
# carico il file 1wav15/pp/pp_7222.wav, 179 files remaining
# carico il file 1wav15/pp/pp_7223.wav, 178 files remaining
# carico il file 1wav15/pp/pp_7224.wav, 177 files remaining
# carico il file 1wav15/pp/pp_7225.wav, 176 files remaining
# carico il file 1wav15/pp/pp_7226.wav, 175 files remaining
# carico il file 1wav15/pp/pp_7227.wav, 174 files remaining
# carico il file 1wav15/pp/pp_7228.wav, 173 files remaining
# carico il file 1wav15/pp/pp_7229.wav, 172 files remaining
# carico il file 1wav15/pp/pp_7230.wav, 171 files remaining
# carico il file 1wav15/pp/pp_7231.wav, 170 files remaining
# carico il file 1wav15/pp/pp_7232.wav, 169 files remaining
# carico il file 1wav15/pp/pp_7233.wav, 168 files remaining
# carico il file 1wav15/pp/pp_7234.wav, 167 files remaining
# carico il file 1wav15/pp/pp_7235.wav, 166 files remaining
# carico il file 1wav15/pp/pp_7236.wav, 165 files remaining
# carico il file 1wav15/pp/pp_7237.wav, 164 files remaining
# carico il file 1wav15/pp/pp_7238.wav, 163 files remaining
# carico il file 1wav15/pp/pp_7239.wav, 162 files remaining
# carico il file 1wav15/pp/pp_7240.wav, 161 files remaining
# carico il file 1wav15/pp/pp_7241.wav, 160 files remaining
# carico il file 1wav15/pp/pp_7242.wav, 159 files remaining
# carico il file 1wav15/pp/pp_7243.wav, 158 files remaining
# carico il file 1wav15/pp/pp_7244.wav, 157 files remaining
# carico il file 1wav15/pp/pp_7245.wav, 156 files remaining
# carico il file 1wav15/pp/pp_7246.wav, 155 files remaining
# carico il file 1wav15/pp/pp_7247.wav, 154 files remaining
# carico il file 1wav15/pp/pp_7248.wav, 153 files remaining
# carico il file 1wav15/pp/pp_7249.wav, 152 files remaining
# carico il file 1wav15/pp/pp_7250.wav, 151 files remaining
# carico il file 1wav15/pp/pp_7251.wav, 150 files remaining
# carico il file 1wav15/pp/pp_7252.wav, 149 files remaining
# carico il file 1wav15/pp/pp_7253.wav, 148 files remaining
# carico il file 1wav15/pp/pp_7254.wav, 147 files remaining
# carico il file 1wav15/pp/pp_7255.wav, 146 files remaining
# carico il file 1wav15/pp/pp_7256.wav, 145 files remaining
# carico il file 1wav15/pp/pp_7257.wav, 144 files remaining
# carico il file 1wav15/pp/pp_7258.wav, 143 files remaining
# carico il file 1wav15/pp/pp_7259.wav, 142 files remaining
# carico il file 1wav15/pp/pp_7260.wav, 141 files remaining
# carico il file 1wav15/pp/pp_7261.wav, 140 files remaining
# carico il file 1wav15/pp/pp_7262.wav, 139 files remaining
# carico il file 1wav15/pp/pp_7263.wav, 138 files remaining
# carico il file 1wav15/pp/pp_7264.wav, 137 files remaining
# carico il file 1wav15/pp/pp_7265.wav, 136 files remaining
# carico il file 1wav15/pp/pp_7266.wav, 135 files remaining
# carico il file 1wav15/pp/pp_7267.wav, 134 files remaining
# carico il file 1wav15/pp/pp_7268.wav, 133 files remaining
# carico il file 1wav15/pp/pp_7269.wav, 132 files remaining
# carico il file 1wav15/pp/pp_7270.wav, 131 files remaining
# carico il file 1wav15/pp/pp_7271.wav, 130 files remaining
# carico il file 1wav15/pp/pp_7272.wav, 129 files remaining
# carico il file 1wav15/pp/pp_7273.wav, 128 files remaining
# carico il file 1wav15/pp/pp_7274.wav, 127 files remaining
# carico il file 1wav15/pp/pp_7275.wav, 126 files remaining
# carico il file 1wav15/pp/pp_7276.wav, 125 files remaining
# carico il file 1wav15/pp/pp_7277.wav, 124 files remaining
# carico il file 1wav15/pp/pp_7278.wav, 123 files remaining
# carico il file 1wav15/pp/pp_7279.wav, 122 files remaining
# carico il file 1wav15/pp/pp_7280.wav, 121 files remaining
# carico il file 1wav15/pp/pp_7281.wav, 120 files remaining
# carico il file 1wav15/pp/pp_7282.wav, 119 files remaining
# carico il file 1wav15/pp/pp_7283.wav, 118 files remaining
# carico il file 1wav15/pp/pp_7284.wav, 117 files remaining
# carico il file 1wav15/pp/pp_7285.wav, 116 files remaining
# carico il file 1wav15/pp/pp_7286.wav, 115 files remaining
# carico il file 1wav15/pp/pp_7287.wav, 114 files remaining
# carico il file 1wav15/pp/pp_7288.wav, 113 files remaining
# carico il file 1wav15/pp/pp_7289.wav, 112 files remaining
# carico il file 1wav15/pp/pp_7290.wav, 111 files remaining
# carico il file 1wav15/pp/pp_7291.wav, 110 files remaining
# carico il file 1wav15/pp/pp_7292.wav, 109 files remaining
# carico il file 1wav15/pp/pp_7293.wav, 108 files remaining
# carico il file 1wav15/pp/pp_7294.wav, 107 files remaining
# carico il file 1wav15/pp/pp_7295.wav, 106 files remaining
# carico il file 1wav15/pp/pp_7296.wav, 105 files remaining
# carico il file 1wav15/pp/pp_7297.wav, 104 files remaining
# carico il file 1wav15/pp/pp_7298.wav, 103 files remaining
# carico il file 1wav15/pp/pp_7299.wav, 102 files remaining
# carico il file 1wav15/pp/pp_7300.wav, 101 files remaining
# carico il file 1wav15/pp/pp_7301.wav, 100 files remaining
# carico il file 1wav15/pp/pp_7302.wav, 99 files remaining
# carico il file 1wav15/pp/pp_7303.wav, 98 files remaining
# carico il file 1wav15/pp/pp_7304.wav, 97 files remaining
# carico il file 1wav15/pp/pp_7305.wav, 96 files remaining
# carico il file 1wav15/pp/pp_7306.wav, 95 files remaining
# carico il file 1wav15/pp/pp_7307.wav, 94 files remaining
# carico il file 1wav15/pp/pp_7308.wav, 93 files remaining
# carico il file 1wav15/pp/pp_7309.wav, 92 files remaining
# carico il file 1wav15/pp/pp_7310.wav, 91 files remaining
# carico il file 1wav15/pp/pp_7311.wav, 90 files remaining
# carico il file 1wav15/pp/pp_7312.wav, 89 files remaining
# carico il file 1wav15/pp/pp_7313.wav, 88 files remaining
# carico il file 1wav15/pp/pp_7314.wav, 87 files remaining
# carico il file 1wav15/pp/pp_7315.wav, 86 files remaining
# carico il file 1wav15/pp/pp_7316.wav, 85 files remaining
# carico il file 1wav15/pp/pp_7317.wav, 84 files remaining
# carico il file 1wav15/pp/pp_7318.wav, 83 files remaining
# carico il file 1wav15/pp/pp_7319.wav, 82 files remaining
# carico il file 1wav15/pp/pp_7320.wav, 81 files remaining
# carico il file 1wav15/pp/pp_7321.wav, 80 files remaining
# carico il file 1wav15/pp/pp_7322.wav, 79 files remaining
# carico il file 1wav15/pp/pp_7323.wav, 78 files remaining
# carico il file 1wav15/pp/pp_7324.wav, 77 files remaining
# carico il file 1wav15/pp/pp_7325.wav, 76 files remaining
# carico il file 1wav15/pp/pp_7326.wav, 75 files remaining
# carico il file 1wav15/pp/pp_7327.wav, 74 files remaining
# carico il file 1wav15/pp/pp_7328.wav, 73 files remaining
# carico il file 1wav15/pp/pp_7329.wav, 72 files remaining
# carico il file 1wav15/pp/pp_7330.wav, 71 files remaining
# carico il file 1wav15/pp/pp_7331.wav, 70 files remaining
# carico il file 1wav15/pp/pp_7332.wav, 69 files remaining
# carico il file 1wav15/pp/pp_7333.wav, 68 files remaining
# carico il file 1wav15/pp/pp_7334.wav, 67 files remaining
# carico il file 1wav15/pp/pp_7335.wav, 66 files remaining
# carico il file 1wav15/pp/pp_7336.wav, 65 files remaining
# carico il file 1wav15/pp/pp_7337.wav, 64 files remaining
# carico il file 1wav15/pp/pp_7338.wav, 63 files remaining
# carico il file 1wav15/pp/pp_7339.wav, 62 files remaining
# carico il file 1wav15/pp/pp_7340.wav, 61 files remaining
# carico il file 1wav15/pp/pp_7341.wav, 60 files remaining
# carico il file 1wav15/pp/pp_7342.wav, 59 files remaining
# carico il file 1wav15/pp/pp_7343.wav, 58 files remaining
# carico il file 1wav15/pp/pp_7344.wav, 57 files remaining
# carico il file 1wav15/pp/pp_7345.wav, 56 files remaining
# carico il file 1wav15/pp/pp_7346.wav, 55 files remaining
# carico il file 1wav15/pp/pp_7347.wav, 54 files remaining
# carico il file 1wav15/pp/pp_7348.wav, 53 files remaining
# carico il file 1wav15/pp/pp_7349.wav, 52 files remaining
# carico il file 1wav15/pp/pp_7350.wav, 51 files remaining
# carico il file 1wav15/pp/pp_7351.wav, 50 files remaining
# carico il file 1wav15/pp/pp_7352.wav, 49 files remaining
# carico il file 1wav15/pp/pp_7353.wav, 48 files remaining
# carico il file 1wav15/pp/pp_7354.wav, 47 files remaining
# carico il file 1wav15/pp/pp_7355.wav, 46 files remaining
# carico il file 1wav15/pp/pp_7356.wav, 45 files remaining
# carico il file 1wav15/pp/pp_7357.wav, 44 files remaining
# carico il file 1wav15/pp/pp_7358.wav, 43 files remaining
# carico il file 1wav15/pp/pp_7359.wav, 42 files remaining
# carico il file 1wav15/pp/pp_7360.wav, 41 files remaining
# carico il file 1wav15/pp/pp_7361.wav, 40 files remaining
# carico il file 1wav15/pp/pp_7362.wav, 39 files remaining
# carico il file 1wav15/pp/pp_7363.wav, 38 files remaining
# carico il file 1wav15/pp/pp_7364.wav, 37 files remaining
# carico il file 1wav15/pp/pp_7365.wav, 36 files remaining
# carico il file 1wav15/pp/pp_7366.wav, 35 files remaining
# carico il file 1wav15/pp/pp_7367.wav, 34 files remaining
# carico il file 1wav15/pp/pp_7368.wav, 33 files remaining
# carico il file 1wav15/pp/pp_7369.wav, 32 files remaining
# carico il file 1wav15/pp/pp_7370.wav, 31 files remaining
# carico il file 1wav15/pp/pp_7371.wav, 30 files remaining
# carico il file 1wav15/pp/pp_7372.wav, 29 files remaining
# carico il file 1wav15/pp/pp_7373.wav, 28 files remaining
# carico il file 1wav15/pp/pp_7374.wav, 27 files remaining
# carico il file 1wav15/pp/pp_7375.wav, 26 files remaining
# carico il file 1wav15/pp/pp_7376.wav, 25 files remaining
# carico il file 1wav15/pp/pp_7377.wav, 24 files remaining
# carico il file 1wav15/pp/pp_7378.wav, 23 files remaining
# carico il file 1wav15/pp/pp_7379.wav, 22 files remaining
# carico il file 1wav15/pp/pp_7380.wav, 21 files remaining
# carico il file 1wav15/pp/pp_7381.wav, 20 files remaining
# carico il file 1wav15/pp/pp_7382.wav, 19 files remaining
# carico il file 1wav15/pp/pp_7383.wav, 18 files remaining
# carico il file 1wav15/pp/pp_7384.wav, 17 files remaining
# carico il file 1wav15/pp/pp_7385.wav, 16 files remaining
# carico il file 1wav15/pp/pp_7386.wav, 15 files remaining
# carico il file 1wav15/pp/pp_7387.wav, 14 files remaining
# carico il file 1wav15/pp/pp_7388.wav, 13 files remaining
# carico il file 1wav15/pp/pp_7389.wav, 12 files remaining
# carico il file 1wav15/pp/pp_7390.wav, 11 files remaining
# carico il file 1wav15/pp/pp_7391.wav, 10 files remaining
# carico il file 1wav15/pp/pp_7392.wav, 9 files remaining
# carico il file 1wav15/pp/pp_7393.wav, 8 files remaining
# carico il file 1wav15/pp/pp_7394.wav, 7 files remaining
# carico il file 1wav15/pp/pp_7395.wav, 6 files remaining
# carico il file 1wav15/pp/pp_7396.wav, 5 files remaining
# carico il file 1wav15/pp/pp_7397.wav, 4 files remaining
# carico il file 1wav15/pp/pp_7398.wav, 3 files remaining
# carico il file 1wav15/pp/pp_7399.wav, 2 files remaining
# carico il file 1wav15/pp/pp_7400.wav, 1 files remaining

# %%
#=============================================================================
#   NON RANDOMIZZO QUESTI DATI IN MODO DA AVERE VALIDATION E TEST SEPARATI   #
#=============================================================================

# %%
#==========================================
#               SALVO I FILE              #
#==========================================

# %%
#salvataggio timestamps
audiosNump = numpy.array(audios[0:N_INPUT_FILES])

print(f'ho {audiosNump.shape[0]} file lunghi {audiosNump.shape[1]}\n\n\n')
print(audiosNump)
# Out:
# ho 1400 file lunghi 330750
#
#
#
# [[ 0.02039713 -0.00892869 -0.10218847 ... -0.06000843  0.19248854
#    0.19606805]
#  [ 0.01537466  0.21760198  0.19000241 ... -0.52187055 -0.3445645
#   -0.25470343]
#  [-0.17081414 -0.3499852  -0.31729415 ...  0.25874344  0.24999198
#    0.29651648]
#  ...
#  [ 0.2030605   0.22745991  0.1590311  ...  0.00472674  0.00620514
#   -0.00087829]
#  [-0.00902959 -0.02761841 -0.04390585 ... -0.16979946  0.00820185
#    0.10864095]
#  [ 0.0526168   0.02559713  0.0212164  ... -0.23658825 -0.26421386
#   -0.272665  ]]

# %%
for n_file in range (N_INPUT_FILES):
    out_location = OUTPUT_FOLDER+str(n_file+START)+'.npy' 
    np.save(out_location,audiosNump[n_file])

# %%
print('DONE')
# Out:
# DONE
